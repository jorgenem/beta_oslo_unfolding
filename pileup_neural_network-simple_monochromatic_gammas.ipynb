# %% [markdown]
# I am testing using a neural network to recognise patterns in the pileup spectra, so that we can revert from a piled-up 1-D spectrum to the underlying 2-D spectrum. First I simulate pairs of piled, original spectra, then I make the network.

# %%
from importlib import reload
from utilities import *
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import os

# %% [markdown]
# # Simulate spectra.
# Assume only multiplicity 2, and set the pileup probability to 1 for this test.
# Later we must check how an energy-dependent pileup probability affects things.

# %%
# Set some global variables:
N_events = int(30*1e3)
customLogNorm = LogNorm(vmin=1e0, vmax=N_events)
np.random.seed(124356)

# %%
# Import response matrix

fname_resp = 'resp-SuN2015-20keV-1p0FWHM.dat'
fname_resp_mat = 'response_matrix-SuN2015-20keV-1p0FWHM.m'
# fname_resp = 'resp-SuN2015-50keV-1p0FWHM.dat'
# fname_resp_mat = 'response_matrix-SuN2015-50keV-1p0FWHM.m'
R_2D, cal_resp, E_resp_array, tmp = read_mama_2D(fname_resp_mat)
# R_2D = div0(R_2D , R_2D.sum(rebin_axis=1))

# Read efficiency and other 1-D response variables:
resp = []
with open(fname_resp) as file:
    # Read line by line as there is crazyness in the file format
    lines = file.readlines()
    for i in range(4,len(lines)):
        try:
            row = np.array(lines[i].split(), dtype="double")
            resp.append(row)
        except:
            break

resp = np.array(resp)
# Name the columns for ease of reading
# FWHM = resp[:,1]
eff = resp[:,2]
# pf = resp[:,3]
# pc = resp[:,4]
# ps = resp[:,5]
# pd = resp[:,6]
# pa = resp[:,7]



Emax = 4000 # Crop response matrix (and thus also event generation) to efficiate computation
i_Emax = np.argmin(np.abs(E_resp_array-Emax))
R_2D = R_2D[0:i_Emax,0:i_Emax]
E_resp_array = E_resp_array[0:i_Emax]



# Assumed lower threshold for gammas in response matrix
E_thres = 100
i_thres = np.argmin(np.abs(E_resp_array - E_thres))
R_2D[:,:i_thres] = 0

for i in range(R_2D.shape[0]):
    norm = R_2D[i,:].sum()
    if(norm>0):
        R_2D[i,:] = R_2D[i,:] / norm #* eff[i]
    else:
        R_2D[i,:] = 0

# %%
# === Folding function for a single event ===
def FoldEg(Egs_t, Mf_max, Eg_arr, response, pileup=True, p_pile=0.2):
    """
    This function folds all Egs from a single event.
    """

    
    # print("Folding. True gammas =", Egs_t, flush=True)
    Mt_curr = len(Egs_t[Egs_t>0]) # Number of true gammas

    
    Mf_curr = Mt_curr # Folded multiplicity is the same as true because we do pileup after energy folding

    # Now proceed to fold each gamma with detector response:
    Egs_folded = np.zeros(Mf_curr)
    for i in range(Mf_curr):
        Eg = Egs_t[i]
        index_Eg = np.argmin(np.abs(Eg_arr - Eg))
        if R_2D[index_Eg,:].sum() > 0:
            # choosing rand accounts for the efficiency; As the efficiency read from file currently
            # does not always correspons with the counts in R_2D, see #3, we need two if tests
            rand = np.random.uniform()
            if rand <= eff[index_Eg]:
                # If the gamma is not lost to efficiency, redistribute its energy somewhere in the response:
                Eg_folded = np.random.choice(Eg_arr, p=response[index_Eg,:])
            else: 
                Eg_folded = 0 # Give Energy 0 to events that are not recorded.
        else: 
            Eg_folded = 0 # Give Energy 0 to events that are not recorded (below detector threshold)

        Egs_folded[i] = Eg_folded


    if pileup: # Is pileup desired?
        # For each folded gamma, assign it to pileup with probability p_pile:
        indices_pile = [] # Store indices in Egs_folded
        counter_nopile = 0
        map_to_pileup = {} # Map the indices that are *not* pileup to a new index set so that there are no index holes
                        # For example if Mt = 3 and index 1 is pileup, then map_nopile = {0:0, 2:1}.
                        # Then we decide which of the new indices to add each pileup event to.
        for i_t in range(Mt_curr):
            # Make sure at least one gamma is not assigned to pileup:
            if i_t == Mt_curr-1 and counter_nopile == 0:
                map_to_pileup[i_t] = counter_nopile
                counter_nopile += 1
                break

            # Also make sure no more than 4 gammas remain, by
            # setting pileup probability to 1 if we already have 4 non-piled
            if counter_nopile == 4:
                p_pile = 1

            r_pile = np.random.uniform()
            if r_pile < p_pile:
                # This gamma should be piled.
                indices_pile.append(i_t)
            else:
                # This gamma should not
                map_to_pileup[i_t] = counter_nopile
                counter_nopile += 1

        # Calculate multiplicity of current event after pileup:
        Mf_curr = Mt_curr - len(indices_pile)

        # Decide mapping of pileup gammas:
        for i_t in indices_pile:
            map_to_pileup[i_t] = np.random.randint(0,Mf_curr) if Mf_curr > 0 else 0

        Egs_piled = np.zeros(Mf_curr)
        for i_t in range(Mt_curr):
            Egs_piled[map_to_pileup[i_t]] += Egs_folded[i_t]

    else:
        # Do not include pileup:
        Egs_piled = Egs_folded
        # Mf_curr = Mt_curr

    # print("Piled gammas =", Egs_piled, flush=True)

    return Egs_piled

# %% [markdown]
# # Proof of principle, a single realization:
# Generate true events and plot them:

# %%
Mt_max = 2 # Max true multiplicity 2
events_t = np.zeros((N_events,Mt_max))
Eg_gaussian_centroids = np.array([500,1700,1300,1000])
for i_ev in range(N_events):
    # Mt_curr = np.random.randint(low=1,high=(Mt_max+1))
    Mt_curr = Mt_max # Testing, comparison to the first test we did with 2 gammas for the report
    # Egs_current = np.random.uniform(low=0, high=Emax, size=Mt_curr)
    Egs_current = np.random.normal(loc=Eg_gaussian_centroids[0:Mt_curr], scale=0.5*np.sqrt(Eg_gaussian_centroids[0:Mt_curr]), size=Mt_curr)
    events_t[i_ev,0:Mt_curr] = Egs_current

# %%
# == Sort and plot true events ==
E_t_array = E_resp_array
N_Eg = len(E_t_array)
counts_true = np.zeros((N_Eg, N_Eg))

# Sort data:
for i_ev in range(N_events):
    counts_true[np.argmin(np.abs(E_t_array-events_t[i_ev,0])),np.argmin(np.abs(E_t_array-events_t[i_ev,1]))] += 1

# Plot by Eg axes
cbar = plt.pcolormesh(E_t_array, E_t_array, counts_true, cmap="jet", norm=customLogNorm)
plt.colorbar(cbar)
plt.show()

# %%
# Simulate pileup
pileup = True
p_pile = 1
Mf_max = 1
events_f = np.zeros((N_events, Mf_max))
for i_ev in range(N_events):
    Egs_folded = FoldEg(events_t[i_ev,:], Mf_max=4, Eg_arr=E_resp_array, response=R_2D, pileup=pileup, p_pile=p_pile)
    events_f[i_ev,0:len(Egs_folded)] = Egs_folded

# %%
# Sort and plot piled events (1-D spectrum since p_pile = 1)
E_f_array = E_resp_array
N_Eg = len(E_f_array)
counts_folded = np.zeros((N_Eg))

# Sort data:
for i_ev in range(N_events):
    counts_folded[np.argmin(np.abs(E_f_array-events_f[i_ev,0]))] += 1

# Plot by Eg axes
cbar = plt.plot(E_t_array, counts_folded)
plt.show()

# %% [markdown]
# # It works, now generate an ensemble of spectra

# %%
# Generate true events:
N_ensemble = 200
N_events = int(30*1e3) # Events per ensemble
Mt_max = 2 # Max true multiplicity 2
purge_files = False # Regenerate simulations?

# Set calibration to use, should not be too large because of neural network
a0, a1 = 0, 100 # keV
N_nn = int(Emax/a1 - a0)

fname_ensemble_counts_true = "ensemble_counts_true-"+str(N_ensemble)+"members.npy"
if os.path.exists(fname_ensemble_counts_true) and not purge_files:
    ensemble_counts_true = np.load(fname_ensemble_counts_true)
    ensemble_counts_true = ensemble_counts_true.reshape((N_ensemble, N_nn, N_nn))
else:
    E_nn_array = np.linspace(a0, a0+(N_nn-1)*a1, N_nn)

    memory_requirement = N_ensemble*N_events*Mt_max*8 / (1024)**2 # MB
    print("memory required to store event lists: {:.2f} MB".format(memory_requirement), flush=True)

    ensemble_list_true = []
    for i_ens in range(N_ensemble):
        events_t = np.zeros((N_events,Mt_max))
        # Draw gaussian centroids randomly up to half of the maximum response array energy
        Eg_gaussian_centroids = np.random.uniform(low=300, high=E_resp_array[-1]/2, size=Mt_max)
        if i_ens % 10 == 0:
            print("Ensemble member {:d}, Egs = {:.2f}, {:.2f}".format(i_ens, Eg_gaussian_centroids[0], Eg_gaussian_centroids[1]), flush=True)
        for i_ev in range(N_events):
            # Mt_curr = np.random.randint(low=1,high=(Mt_max+1))
            Mt_curr = Mt_max # Testing, comparison to the first test we did with 2 gammas for the report
            # Egs_current = np.random.uniform(low=0, high=Emax, size=Mt_curr)
            Egs_current = np.random.normal(loc=Eg_gaussian_centroids[0:Mt_curr], scale=0.5*np.sqrt(Eg_gaussian_centroids[0:Mt_curr]), size=Mt_curr)
            events_t[i_ev,0:Mt_curr] = Egs_current   
        ensemble_list_true.append(events_t)

    
    
    
    # Sort each ensemble member and plot a random member:
    E_t_array = E_resp_array
    N_Eg = len(E_t_array)

    # Sort data:
    #counts_true = np.zeros((N_nn, N_nn))
    ensemble_counts_true = np.zeros((N_ensemble, N_nn, N_nn))
    print("Sorting data", flush=True)
    for i_ens in range(N_ensemble):
        events_t = ensemble_list_true[i_ens]
        for i_ev in range(N_events):
            ensemble_counts_true[i_ens, np.argmin(np.abs(E_nn_array-events_t[i_ev,0])), np.argmin(np.abs(E_nn_array-events_t[i_ev,1]))] += 1

    np.save(fname_ensemble_counts_true, ensemble_counts_true)
# Out:
# memory required to store events: 91.55 MB
# Ensemble member 0, Egs = 1760.13, 926.66
# Ensemble member 1, Egs = 493.61, 771.47
# Ensemble member 2, Egs = 466.15, 759.66
# Ensemble member 3, Egs = 357.86, 1691.50
# Ensemble member 4, Egs = 931.09, 1984.29
# Ensemble member 5, Egs = 1473.05, 1898.96
# Ensemble member 6, Egs = 1640.18, 1054.85
# Ensemble member 7, Egs = 1953.90, 1234.85
# Ensemble member 8, Egs = 1281.02, 1386.93
# Ensemble member 9, Egs = 856.87, 337.04
# Ensemble member 10, Egs = 907.89, 425.05
# Ensemble member 11, Egs = 1576.15, 683.86
# Ensemble member 12, Egs = 1787.72, 1271.04
# Ensemble member 13, Egs = 1608.57, 1773.29
# Ensemble member 14, Egs = 1280.14, 1137.57
# Ensemble member 15, Egs = 1374.98, 403.41
# Ensemble member 16, Egs = 1941.89, 676.55
# Ensemble member 17, Egs = 1047.65, 1273.80
# Ensemble member 18, Egs = 788.69, 581.60
# Ensemble member 19, Egs = 1407.43, 1469.25
# Ensemble member 20, Egs = 311.72, 1073.27
# Ensemble member 21, Egs = 1588.72, 578.18
# Ensemble member 22, Egs = 687.84, 721.40
# Ensemble member 23, Egs = 402.08, 1233.98
# Ensemble member 24, Egs = 637.62, 1944.57
# Ensemble member 25, Egs = 1377.50, 323.41
# Ensemble member 26, Egs = 430.00, 642.41
# Ensemble member 27, Egs = 326.75, 680.50
# Ensemble member 28, Egs = 1254.41, 329.87
# Ensemble member 29, Egs = 1565.50, 397.54
# Ensemble member 30, Egs = 1017.13, 528.30
# Ensemble member 31, Egs = 1038.63, 1186.23
# Ensemble member 32, Egs = 568.68, 961.26
# Ensemble member 33, Egs = 971.69, 1637.86
# Ensemble member 34, Egs = 1282.92, 1221.88
# Ensemble member 35, Egs = 724.82, 1637.38
# Ensemble member 36, Egs = 1567.66, 1551.99
# Ensemble member 37, Egs = 455.41, 652.58
# Ensemble member 38, Egs = 428.29, 1045.90
# Ensemble member 39, Egs = 1673.61, 629.29
# Ensemble member 40, Egs = 1860.18, 1453.34
# Ensemble member 41, Egs = 1495.28, 1007.97
# Ensemble member 42, Egs = 1266.62, 783.46
# Ensemble member 43, Egs = 1775.18, 566.17
# Ensemble member 44, Egs = 1713.28, 1318.27
# Ensemble member 45, Egs = 1297.97, 865.27
# Ensemble member 46, Egs = 1166.51, 1604.45
# Ensemble member 47, Egs = 1463.49, 1414.41
# Ensemble member 48, Egs = 856.82, 1555.08
# Ensemble member 49, Egs = 706.38, 872.18
# Ensemble member 50, Egs = 1097.68, 1681.50
# Ensemble member 51, Egs = 1114.36, 1426.57
# Ensemble member 52, Egs = 1641.09, 1281.62
# Ensemble member 53, Egs = 340.77, 1450.32
# Ensemble member 54, Egs = 712.57, 1773.63
# Ensemble member 55, Egs = 1713.95, 472.24
# Ensemble member 56, Egs = 1151.78, 574.14
# Ensemble member 57, Egs = 1198.34, 445.05
# Ensemble member 58, Egs = 1648.01, 1562.18
# Ensemble member 59, Egs = 1389.06, 1861.87
# Ensemble member 60, Egs = 1546.71, 1505.53
# Ensemble member 61, Egs = 1675.94, 1183.01
# Ensemble member 62, Egs = 968.05, 1841.75
# Ensemble member 63, Egs = 611.41, 439.80
# Ensemble member 64, Egs = 453.63, 866.96
# Ensemble member 65, Egs = 391.89, 1648.47
# Ensemble member 66, Egs = 745.91, 1513.61
# Ensemble member 67, Egs = 1209.47, 1161.56
# Ensemble member 68, Egs = 658.83, 412.82
# Ensemble member 69, Egs = 334.82, 1674.57
# Ensemble member 70, Egs = 1783.72, 313.74
# Ensemble member 71, Egs = 1878.55, 1665.99
# Ensemble member 72, Egs = 1763.76, 487.09
# Ensemble member 73, Egs = 432.76, 1517.01
# Ensemble member 74, Egs = 935.12, 921.89
# Ensemble member 75, Egs = 1646.77, 1143.12
# Ensemble member 76, Egs = 1866.48, 1671.42
# Ensemble member 77, Egs = 566.84, 988.19
# Ensemble member 78, Egs = 1403.76, 516.09
# Ensemble member 79, Egs = 471.40, 989.06
# Ensemble member 80, Egs = 652.39, 664.02
# Ensemble member 81, Egs = 1789.23, 734.52
# Ensemble member 82, Egs = 519.22, 1307.10
# Ensemble member 83, Egs = 731.06, 371.31
# Ensemble member 84, Egs = 1809.07, 1577.19
# Ensemble member 85, Egs = 391.20, 1421.55
# Ensemble member 86, Egs = 1506.40, 643.49
# Ensemble member 87, Egs = 1141.15, 611.14
# Ensemble member 88, Egs = 1974.74, 1260.31
# Ensemble member 89, Egs = 775.81, 1445.10
# Ensemble member 90, Egs = 622.50, 1281.86
# Ensemble member 91, Egs = 1454.61, 707.85
# Ensemble member 92, Egs = 426.82, 1965.16
# Ensemble member 93, Egs = 1195.36, 579.14
# Ensemble member 94, Egs = 1103.86, 920.89
# Ensemble member 95, Egs = 1345.05, 1828.32
# Ensemble member 96, Egs = 463.90, 444.66
# Ensemble member 97, Egs = 738.32, 1851.66
# Ensemble member 98, Egs = 523.93, 451.99
# Ensemble member 99, Egs = 480.66, 1426.53
# Ensemble member 100, Egs = 1874.91, 384.64
# Ensemble member 101, Egs = 1812.76, 657.80
# Ensemble member 102, Egs = 1526.64, 1812.62
# Ensemble member 103, Egs = 1908.66, 966.15
# Ensemble member 104, Egs = 1621.00, 1715.33
# Ensemble member 105, Egs = 1817.89, 1337.46
# Ensemble member 106, Egs = 1325.27, 599.85
# Ensemble member 107, Egs = 506.70, 747.50
# Ensemble member 108, Egs = 1748.53, 839.75
# Ensemble member 109, Egs = 938.60, 313.37
# Ensemble member 110, Egs = 687.92, 1118.65
# Ensemble member 111, Egs = 397.86, 1770.87
# Ensemble member 112, Egs = 1171.60, 1395.67
# Ensemble member 113, Egs = 1223.12, 1206.20
# Ensemble member 114, Egs = 1547.88, 1984.46
# Ensemble member 115, Egs = 712.18, 1626.04
# Ensemble member 116, Egs = 505.06, 1471.98
# Ensemble member 117, Egs = 746.00, 988.90
# Ensemble member 118, Egs = 481.12, 954.09
# Ensemble member 119, Egs = 371.75, 1724.96
# Ensemble member 120, Egs = 627.32, 1432.70
# Ensemble member 121, Egs = 449.31, 746.59
# Ensemble member 122, Egs = 1777.08, 1529.69
# Ensemble member 123, Egs = 1012.67, 1581.95
# Ensemble member 124, Egs = 858.19, 1458.53
# Ensemble member 125, Egs = 1726.60, 662.55
# Ensemble member 126, Egs = 1410.99, 657.11
# Ensemble member 127, Egs = 301.75, 733.39
# Ensemble member 128, Egs = 820.56, 940.26
# Ensemble member 129, Egs = 1583.73, 1372.22
# Ensemble member 130, Egs = 1793.90, 1091.01
# Ensemble member 131, Egs = 506.20, 1343.57
# Ensemble member 132, Egs = 1962.15, 1837.02
# Ensemble member 133, Egs = 1315.68, 1261.95
# Ensemble member 134, Egs = 1478.80, 369.64
# Ensemble member 135, Egs = 1196.99, 1245.90
# Ensemble member 136, Egs = 1179.21, 473.42
# Ensemble member 137, Egs = 1133.12, 1830.69
# Ensemble member 138, Egs = 1695.00, 834.33
# Ensemble member 139, Egs = 1301.42, 1115.18
# Ensemble member 140, Egs = 1232.63, 1024.15
# Ensemble member 141, Egs = 1922.27, 701.88
# Ensemble member 142, Egs = 988.94, 1906.79
# Ensemble member 143, Egs = 1394.53, 1334.29
# Ensemble member 144, Egs = 1297.63, 1634.94
# Ensemble member 145, Egs = 590.33, 461.80
# Ensemble member 146, Egs = 604.05, 784.06
# Ensemble member 147, Egs = 1969.43, 1829.81
# Ensemble member 148, Egs = 1498.75, 781.58
# Ensemble member 149, Egs = 1775.48, 1531.07
# Ensemble member 150, Egs = 932.15, 722.78
# Ensemble member 151, Egs = 1193.19, 606.09
# Ensemble member 152, Egs = 874.93, 1888.97
# Ensemble member 153, Egs = 1640.40, 1821.57
# Ensemble member 154, Egs = 1339.22, 562.07
# Ensemble member 155, Egs = 1815.61, 753.38
# Ensemble member 156, Egs = 566.87, 968.59
# Ensemble member 157, Egs = 965.83, 1518.48
# Ensemble member 158, Egs = 775.64, 898.72
# Ensemble member 159, Egs = 926.60, 1158.37
# Ensemble member 160, Egs = 1287.39, 654.12
# Ensemble member 161, Egs = 1359.38, 1903.48
# Ensemble member 162, Egs = 847.60, 1249.06
# Ensemble member 163, Egs = 1911.39, 971.56
# Ensemble member 164, Egs = 729.56, 1923.80
# Ensemble member 165, Egs = 1952.33, 977.87
# Ensemble member 166, Egs = 1833.33, 783.48
# Ensemble member 167, Egs = 1780.85, 449.39
# Ensemble member 168, Egs = 990.61, 1759.78
# Ensemble member 169, Egs = 636.28, 536.69
# Ensemble member 170, Egs = 1741.04, 1829.52
# Ensemble member 171, Egs = 1291.35, 998.39
# Ensemble member 172, Egs = 1325.73, 1932.23
# Ensemble member 173, Egs = 701.46, 948.17
# Ensemble member 174, Egs = 691.90, 351.70
# Ensemble member 175, Egs = 949.07, 609.82
# Ensemble member 176, Egs = 1973.26, 935.11
# Ensemble member 177, Egs = 1570.84, 1656.94
# Ensemble member 178, Egs = 1725.29, 1823.49
# Ensemble member 179, Egs = 1977.24, 522.90
# Ensemble member 180, Egs = 1751.69, 1670.99
# Ensemble member 181, Egs = 1233.22, 307.90
# Ensemble member 182, Egs = 375.69, 619.76
# Ensemble member 183, Egs = 1179.49, 943.48
# Ensemble member 184, Egs = 1480.39, 1212.60
# Ensemble member 185, Egs = 1229.73, 945.59
# Ensemble member 186, Egs = 1520.81, 1234.83
# Ensemble member 187, Egs = 1109.15, 1824.90
# Ensemble member 188, Egs = 968.53, 1765.65
# Ensemble member 189, Egs = 1648.53, 803.61
# Ensemble member 190, Egs = 802.10, 496.12
# Ensemble member 191, Egs = 1017.45, 1200.40
# Ensemble member 192, Egs = 1830.29, 504.07
# Ensemble member 193, Egs = 1666.85, 1050.77
# Ensemble member 194, Egs = 556.60, 1547.31
# Ensemble member 195, Egs = 1689.77, 600.82
# Ensemble member 196, Egs = 1185.76, 540.60
# Ensemble member 197, Egs = 1079.34, 458.65
# Ensemble member 198, Egs = 1128.79, 502.61
# Ensemble member 199, Egs = 1954.13, 1577.43

# %%
# Plot by Eg axes
index = np.random.randint(0,N_ensemble-1)
cbar = plt.pcolormesh(E_nn_array, E_nn_array, ensemble_counts_true[index,:,:], cmap="jet", norm=customLogNorm)
plt.colorbar(cbar)
plt.title("Ensemble member "+str(index))
plt.show()

# %%
# Simulate pileup for each member:
pileup = True
p_pile = 1
Mf_max = 1

fname_ensemble_counts_folded = "ensemble_counts_folded-"+str(N_ensemble)+"members.npy"
if os.path.exists(fname_ensemble_counts_folded) and not purge_files:
    ensemble_counts_folded = np.load(fname_ensemble_counts_folded)
    ensemble_counts_folded = ensemble_counts_folded.reshape((N_ensemble, N_nn))
else:
    ensemble_list_folded = []
    for i_ens in range(N_ensemble):
        if i_ens % 10 == 0:
            print("Ensemble member {:d}".format(i_ens), flush=True)
        events_f = np.zeros((N_events, Mf_max))
        for i_ev in range(N_events):
            Egs_folded = FoldEg(events_t[i_ev,:], Mf_max=4, Eg_arr=E_resp_array, response=R_2D, pileup=pileup, p_pile=p_pile)
            events_f[i_ev,0:len(Egs_folded)] = Egs_folded
        ensemble_list_folded.append(events_f)
    
    
    
    # Sort all ensemble members and plot same random member as above:
    ensemble_counts_folded = np.zeros((N_ensemble, N_nn))

    # Sort data:
    events_f = ensemble_list_folded[index]
    for i_ens in range(N_ensemble):
        for i_ev in range(N_events):
            ensemble_counts_folded[i_ens, np.argmin(np.abs(E_nn_array-events_f[i_ev,0]))] += 1

    # Plot by Eg axes
    plt.step(E_nn_array, ensemble_counts_folded[index,:])
    plt.title("Ensemble member "+str(index))
    plt.show()

    np.save(fname_ensemble_counts_folded, ensemble_counts_folded)
# Out:
# Ensemble member 0
# Ensemble member 10
# Ensemble member 20
# Ensemble member 30
# Ensemble member 40
# Ensemble member 50
# Ensemble member 60
# Ensemble member 70
# Ensemble member 80
# Ensemble member 90
# Ensemble member 100
# Ensemble member 110
# Ensemble member 120
# Ensemble member 130
# Ensemble member 140
# Ensemble member 150
# Ensemble member 160
# Ensemble member 170
# Ensemble member 180
# Ensemble member 190

# %% [markdown]
# # Set up the neural network
#
# I try to adapt something from the TensorFlow tutorial:

# %%
train_in = ensemble_counts_folded / ensemble_counts_folded.sum(axis=1).reshape((ensemble_counts_folded.shape[0],1))
print("train_in.shape =", train_in.shape)
train_out = ensemble_counts_true / ensemble_counts_true.sum(axis=(1,2)).reshape((ensemble_counts_folded.shape[0],1,1))
train_out = train_out.reshape(N_ensemble, int(N_nn**2))
print("train_out.shape =", train_out.shape)
plt.imshow(train_out[index].reshape(N_nn, N_nn), origin="lower")
plt.colorbar()
# Out:
# train_in.shape = (200, 40)
# train_out.shape = (200, 1600)

# %%
import tensorflow as tf
from tensorflow import keras

model = keras.Sequential([
    keras.layers.Dense(N_nn, activation=tf.nn.relu,
                       input_shape=(N_nn,)),
    keras.layers.Dense(int(N_nn**2), activation=tf.nn.relu),
    #keras.layers.Dense(int(N_nn**2)),
    keras.layers.Dense(int(N_nn**2))
  ])

optimizer = tf.train.RMSPropOptimizer(0.001)

model.compile(loss='mean_squared_error',
            optimizer=optimizer,
            metrics=['mae'])

# %%
# Train network
# Display training progress by printing a single dot for each completed epoch
class PrintDot(keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs):
    if epoch % 100 == 0: print('')
    print('.', end='')
EPOCHS = 500
history = model.fit(train_in, train_out, epochs=EPOCHS,
                    validation_split=0.2, verbose=0,
                    callbacks=[PrintDot()])
# Out:
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
import matplotlib.pyplot as plt


def plot_history(history):
  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('Mean Abs Error')
  plt.plot(history.epoch, np.array(history.history['mean_absolute_error']),
           label='Train Loss')
  plt.plot(history.epoch, np.array(history.history['val_mean_absolute_error']),
           label = 'Val loss')
  plt.legend()
  #plt.ylim([0, 5])

plot_history(history)

# %%
# Generate and check against new test data:
Mt_max = 2 # Max true multiplicity 2
events_t = np.zeros((N_events,Mt_max))
# Simulate pileup
pileup = True
p_pile = 1
Mf_max = 1


np.random.seed(1245)
N_test = 4


fname_ensemble_test_counts_true = "ensemble_test_counts_true-"+str(N_test)+"members.npy"
fname_ensemble_test_counts_folded = "ensemble_test_counts_folded-"+str(N_test)+"members.npy"
if os.path.exists(fname_ensemble_test_counts_true) and os.path.exists(fname_ensemble_test_counts_folded) and not purge_files:
    ensemble_test_counts_true = np.load(fname_ensemble_test_counts_true)
    ensemble_test_counts_true = ensemble_test_counts_true.reshape((N_test, N_nn, N_nn))
    ensemble_test_counts_folded = np.load(fname_ensemble_test_counts_folded)
    ensemble_test_counts_folded = ensemble_test_counts_true.reshape((N_test, N_nn))
else:
    ensemble_test_counts_true = np.zeros((N_test, N_nn, N_nn))
    ensemble_test_counts_folded = np.zeros((N_test, N_nn))
    for i_test in range(N_test):
        events_t = np.zeros((N_events, Mt_max))
        events_f = np.zeros((N_events, Mf_max))
    
        #Eg_gaussian_centroids = np.array([500,1700,1300,1000])
        Eg_gaussian_centroids = np.random.uniform(low=300,high=int(Emax/2),size=Mt_max)
        for i_ev in range(N_events):
            # Mt_curr = np.random.randint(low=1,high=(Mt_max+1))
            Mt_curr = Mt_max # Testing, comparison to the first test we did with 2 gammas for the report
            # Egs_current = np.random.uniform(low=0, high=Emax, size=Mt_curr)
            Egs_current = np.random.normal(loc=Eg_gaussian_centroids[0:Mt_curr], scale=0.5*np.sqrt(Eg_gaussian_centroids[0:Mt_curr]), size=Mt_curr)
            events_t[i_ev,0:Mt_curr] = Egs_current 
            Egs_folded = FoldEg(events_t[i_ev,:], Mf_max=4, Eg_arr=E_resp_array, response=R_2D, pileup=pileup, p_pile=p_pile)
            events_f[i_ev,0:len(Egs_folded)] = Egs_folded  

            # Sort:
            ensemble_test_counts_true[i_test, np.argmin(np.abs(E_nn_array-events_t[i_ev,0])), np.argmin(np.abs(E_nn_array-events_t[i_ev,1]))] += 1
            ensemble_test_counts_folded[i_test, np.argmin(np.abs(E_nn_array-events_f[i_ev,0]))] += 1
            
            
            
    np.save(fname_ensemble_test_counts_true, ensemble_test_counts_true)
    np.save(fname_ensemble_test_counts_folded, ensemble_test_counts_folded)
            
            
ensemble_test_counts_true /= ensemble_test_counts_true.sum(axis=(1,2)).reshape((ensemble_test_counts_folded.shape[0],1,1))
ensemble_test_counts_folded /= ensemble_test_counts_folded.sum(axis=1).reshape((ensemble_test_counts_folded.shape[0],1))

# %%
# Plot true and predicted
f, axs = plt.subplots(N_test,3)

for i_test in range(N_test):
    axs[i_test,0].step(E_nn_array, ensemble_test_counts_folded[i_test,:])
    cbar2 = axs[i_test,1].imshow(ensemble_test_counts_true[i_test,:,:], origin="lower")

    ensemble_test_counts_predicted = model.predict(ensemble_test_counts_folded)
    ensemble_test_counts_predicted = ensemble_test_counts_predicted.reshape((N_test, N_nn, N_nn))
    cbar3 = axs[i_test,2].imshow(ensemble_test_counts_predicted[i_test,:,:], origin="lower")
        
    ax1.set_title("Input folded spectrum")
    ax2.set_title("True spectrum")
    ax3.set_title("NN predicted spectrum")

    
    f.colorbar(cbar2, ax=axs[i_test,1])
    f.colorbar(cbar3, ax=axs[i_test,2])
f.set_size_inches(12,3*N_test)
